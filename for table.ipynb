# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import joblib
from joblib import dump, load
import tensorflow as tf
import pandas as pd
import numpy as np
from mlxtend.classifier import StackingClassifier
import joblib
from joblib import dump, load
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, recall_score,precision_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import label_binarize

# %%
X1_train=np.load("X1_train.npy")
y1_train=np.load("Y1_train.npy")
X1_dev = np.load("X1_dev.npy")
Y1_dev = np.load("Y1_dev.npy")
X1_test=np.load("X1_test.npy")
y1_test=np.load("Y1_test.npy")
X1_test2=np.load("X1_test2.npy")
y1_test2=np.load("Y1_test2.npy")

# %%
X2_train=np.load("X2_train.npy")
y2_train=np.load("Y2_train.npy")
X2_dev = np.load("X2_dev.npy")
Y2_dev = np.load("Y2_dev.npy")
X2_test=np.load("X2_test.npy")
y2_test=np.load("Y2_test.npy")
X2_test2=np.load("X2_test2.npy")
y2_test2=np.load("Y2_test2.npy")

# %%
X3_train=np.load("X3_train.npy")
y3_train=np.load("Y3_train.npy")
X3_dev = np.load("X3_dev.npy")
Y3_dev = np.load("Y3_dev.npy")
X3_test=np.load("X3_test.npy")
y3_test=np.load("Y3_test.npy")
X3_test2=np.load("X3_test2.npy")
y3_test2=np.load("Y3_test2.npy")

# %%
X4_train=np.load("X4_train.npy")
y4_train=np.load("Y4_train.npy")
X4_dev = np.load("X4_dev.npy")
Y4_dev = np.load("Y4_dev.npy")
X4_test=np.load("X4_test.npy")
y4_test=np.load("Y4_test.npy")
X4_test2=np.load("X4_test2.npy")
y4_test2=np.load("Y4_test2.npy")

# %%
X5_train=np.load("X5_train.npy")
y5_train=np.load("Y5_train.npy")
X5_dev = np.load("X5_dev.npy")
Y5_dev = np.load("Y5_dev.npy")
X5_test=np.load("X5_test.npy")
y5_test=np.load("Y5_test.npy")
X5_test2=np.load("X5_test2.npy")
y5_test2=np.load("Y5_test2.npy")

# %%
X6_train=np.load("X6_train.npy")
y6_train=np.load("Y6_train.npy")
X6_dev = np.load("X6_dev.npy")
Y6_dev = np.load("Y6_dev.npy")
X6_test=np.load("X6_test.npy")
y6_test=np.load("Y6_test.npy")
X6_test2=np.load("X6_test2.npy")
y6_test2=np.load("Y6_test2.npy")

# %%
X7_train=np.load("X7_train.npy")
y7_train=np.load("Y7_train.npy")
X7_dev = np.load("X7_dev.npy")
Y7_dev = np.load("Y7_dev.npy")
X7_test=np.load("X7_test.npy")
y7_test=np.load("Y7_test.npy")
X7_test2=np.load("X7_test2.npy")
y7_test2=np.load("Y7_test2.npy")

# %%
X8_train=np.load("X8_train.npy")
y8_train=np.load("Y8_train.npy")
X8_dev = np.load("X8_dev.npy")
Y8_dev = np.load("Y8_dev.npy")
X8_test=np.load("X8_test.npy")
y8_test=np.load("Y8_test.npy")
X8_test2=np.load("X8_test2.npy")
y8_test2=np.load("Y8_test2.npy")

# %%
X9_train=np.load("X9_train.npy")
y9_train=np.load("Y9_train.npy")
X9_dev = np.load("X9_dev.npy")
Y9_dev = np.load("Y9_dev.npy")
X9_test=np.load("X9_test.npy")
y9_test=np.load("Y9_test.npy")
X9_test2=np.load("X9_test2.npy")
y9_test2=np.load("Y9_test2.npy")

# %%
X10_train=np.load("X10_train.npy")
y10_train=np.load("Y10_train.npy")
X10_dev = np.load("X10_dev.npy")
Y10_dev = np.load("Y10_dev.npy")
X10_test=np.load("X10_test.npy")
y10_test=np.load("Y10_test.npy")
X10_test2=np.load("X10_test2.npy")
y10_test2=np.load("Y10_test2.npy")

# %%
X11_train=np.load("X11_train.npy")
y11_train=np.load("Y11_train.npy")
#X11_dev = np.load("X11_dev.npy")
#Y11_dev = np.load("Y11_dev.npy")
X11_test=np.load("X11_test.npy")
y11_test=np.load("Y11_test.npy")
X11_test2=np.load("X11_test2.npy")
y11_test2=np.load("Y11_test2.npy")

# %%
# Training of base classifiers

# %%
#S1
#SVM

from sklearn.svm import SVC
svm_rbf1 = SVC( C = 1000, gamma=1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf1.fit(X1_train, y1_train)
# Make predictions
y1_test2_pred = svm_rbf1.predict(X1_test2)
y1_test_pred = svm_rbf1.predict(X1_test)
# Test set2 performance
svm_rbf1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
svm_rbf1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
svm_rbf1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score

# %%
#S1
# Decision Tree

from sklearn.tree import DecisionTreeClassifier
dt1 = DecisionTreeClassifier(max_depth=15, criterion = 'entropy', min_samples_leaf= 3) # Define classifier
dt1.fit(X1_train, y1_train) # Train model
# Make predictions
y1_test2_pred = dt1.predict(X1_test2)
y1_test_pred = dt1.predict(X1_test)
# Test set2 performance
dt1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
dt1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
dt1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score

# %%
#S1
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn1 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn1.fit(X1_train, y1_train) # Train model, x-> features y->classification or class level
# Make predictions
y1_test2_pred = knn1.predict(X1_test2) # predicted value of testing set
y1_testpred = knn1.predict(X1_test) # predicted value of testing set
# Test set2 performance
knn1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
knn1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
knn1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score

# %%
#S1
#logistic regression

from sklearn.linear_model import LogisticRegression
logreg1 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg1.fit(X1_train, y1_train) # Train model, x-> features y->classification or class level
# Make predictions
y1_test2_pred = logreg1.predict(X1_test2) # predicted value of testing set
y1_test_pred = logreg1.predict(X1_test) # predicted value of testing set
# Test set2 performance
logreg1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
logreg1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
logreg1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S2
#SVM

from sklearn.svm import SVC
svm_rbf2 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf2.fit(X2_train, y2_train)
# Make predictions
y2_test2_pred = svm_rbf2.predict(X2_test2)
y2_test_pred = svm_rbf2.predict(X2_test)
# Test set2 performance
svm_rbf2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
svm_rbf2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
svm_rbf2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score

# %%
#S2
# Decision Tree

from sklearn.tree import DecisionTreeClassifier
dt2 = DecisionTreeClassifier(max_depth=50, criterion = 'entropy', min_samples_leaf= 2) # Define classifier
dt2.fit(X2_train, y2_train) # Train model
# Make predictions
y2_test2_pred = dt2.predict(X2_test2)
y2_test_pred = dt2.predict(X2_test)
# Test set2 performance
dt2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
dt2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
dt2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score

# %%
#S2
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn2 = KNeighborsClassifier(metric= 'manhattan', n_neighbors=3, weights='distance') # Define classifier
knn2.fit(X2_train, y2_train) # Train model, x-> features y->classification or class level
# Make predictions
y2_test2_pred = knn2.predict(X2_test2) # predicted value of testing set
y2_test_pred = knn2.predict(X2_test) # predicted value of testing set
# Test set2 performance
knn2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
knn2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
knn2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score

# %%
#S2
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg2 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg2.fit(X2_train, y2_train) # Train model, x-> features y->classification or class level
# Make predictions
y2_test2_pred = logreg2.predict(X2_test2) # predicted value of testing set
y2_test_pred = logreg2.predict(X2_test) # predicted value of testing set
# Test set2 performance
logreg2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
logreg2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
logreg2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S3
#SVM

from sklearn.svm import SVC
svm_rbf3 = SVC( C = 100, gamma=5, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf3.fit(X3_train, y3_train)
# Make predictions
y3_test2_pred = svm_rbf3.predict(X3_test2)
y3_test_pred = svm_rbf3.predict(X3_test)
# Test set2 performance
svm_rbf3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
svm_rbf3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score


# Test set1 performance
svm_rbf3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
svm_rbf3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score

# %%
#S3
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

dt3 = DecisionTreeClassifier(max_depth=50, criterion = 'entropy', min_samples_leaf= 2) # Define classifier
dt3.fit(X3_train, y3_train) # Train model
# Make predictions
y3_test2_pred = dt3.predict(X3_test2)
y3_test_pred = dt3.predict(X3_test)
# Test set2 performance
dt3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
dt3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score

# Test set performance
dt3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
dt3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score

# %%
#S3
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn3 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn3.fit(X3_train, y3_train) # Train model, x-> features y->classification or class level
# Make predictions
y3_test2_pred = knn3.predict(X3_test2) # predicted value of testing set
y3_test_pred = knn3.predict(X3_test) # predicted value of testing set
# Test set2 performance
knn3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
knn3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
knn3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score

# %%
#S3
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg3 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg3.fit(X3_train, y3_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y3_test2_pred = logreg3.predict(X3_test2) # predicted value of testing set
y3_test_pred = logreg3.predict(X3_test) # predicted value of testing set
# Test set2 performance
logreg3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
logreg3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
logreg3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S4
#SVM

from sklearn.svm import SVC
svm_rbf4 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf4.fit(X4_train, y4_train)
# Make predictions
y4_test2_pred = svm_rbf4.predict(X4_test2)
y4_test_pred = svm_rbf4.predict(X4_test)
# Test set2 performance
svm_rbf4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
svm_rbf4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
svm_rbf4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score

# %%
# S4
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt4 = DecisionTreeClassifier(max_depth=25, criterion = 'entropy', min_samples_leaf= 2)
dt4.fit(X4_train, y4_train) # Train model
# Make predictions
y4_test2_pred = dt4.predict(X4_test2)
y4_test_pred = dt4.predict(X4_test)
# Test set2 performance
dt4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
dt4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
dt4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score


print('Model performance for Test set')
print('- Accuracy: %s' % dt4_test2_accuracy)
print('- F1 score: %s' % dt4_test2_f1)
print('----------------------------------')
print('Model performance for Test set')
print('- Accuracy: %s' % dt4_test_accuracy)
print('- F1 score: %s' % dt4_test_f1)
# Out:
# Model performance for Test set
# - Accuracy: 0.8720170454545455
# - F1 score: 0.872513393200363
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.6577909270216963
# - F1 score: 0.6490760566265434

# %%
#S4
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier

knn4 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn4.fit(X4_train, y4_train) # Train model, x-> features y->classification or class level
# Make predictions
y4_test2_pred = knn4.predict(X4_test2) # predicted value of testing set
y4_test_pred = knn4.predict(X4_test) # predicted value of testing set
# Test set2 performance
knn4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
knn4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
knn4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score

# %%
#S4
#logistic regression
from sklearn.linear_model import LogisticRegression
logreg4 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg4.fit(X4_train, y4_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y4_test2_pred = logreg4.predict(X4_test2) # predicted value of testing set
y4_test_pred = logreg4.predict(X4_test) # predicted value of testing set
# Test set2 performance
logreg4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
logreg4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
logreg4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S5
#SVM

from sklearn.svm import SVC
svm_rbf5 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf5.fit(X5_train, y5_train)
# Make predictions
y5_test2_pred = svm_rbf5.predict(X5_test2)
y5_test_pred = svm_rbf5.predict(X5_test)
# Test set2 performance
svm_rbf5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
svm_rbf5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
svm_rbf5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score

# %%
#S5
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt5 = DecisionTreeClassifier(max_depth=15, criterion = 'entropy', min_samples_leaf= 3) # Define classifier
dt5.fit(X5_train, y5_train) # Train model
# Make predictions
y5_test2_pred = dt5.predict(X5_test2)
y5_test_pred = dt5.predict(X5_test)


# Test set2 performance
dt5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
dt5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score

# Test set performance
dt5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
dt5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score

# %%
#S5
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn5 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn5.fit(X5_train, y5_train) # Train model, x-> features y->classification or class level
# Make predictions
y5_test2_pred = knn5.predict(X5_test2) # predicted value of testing set
y5_test_pred = knn5.predict(X5_test) # predicted value of testing set
# Test set2 performance
knn5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
knn5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
knn5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score

# %%
#S5
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg5 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg5.fit(X5_train, y5_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y5_test2_pred = logreg5.predict(X5_test2) # predicted value of testing set
y5_test_pred = logreg5.predict(X5_test) # predicted value of testing set
# Test set2 performance
logreg5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
logreg5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
logreg5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S6
#SVM
from sklearn.svm import SVC
svm_rbf6 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf6.fit(X6_train, y6_train)
# Make predictions
y6_test2_pred = svm_rbf6.predict(X6_test2)
y6_test_pred = svm_rbf6.predict(X6_test)

# Test set1 performance
svm_rbf6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
svm_rbf6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score

# Test set2 performance
svm_rbf6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
svm_rbf6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score

# %%
#S6
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

dt6 = DecisionTreeClassifier(max_depth=25, criterion = 'entropy', min_samples_leaf= 2) # Define classifier
dt6.fit(X6_train, y6_train) # Train model

# Make predictions
y6_test2_pred = dt6.predict(X6_test2)
y6_test_pred = dt6.predict(X6_test)
# Test set2 performance
dt6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
dt6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score

# Test set performance
dt6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
dt6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score

# %%
#S6
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn6 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform') # Define classifier taking nearest neighbour of k as 3
knn6.fit(X6_train, y6_train) # Train model, x-> features y->classification or class level
# Make predictions
y6_test2_pred = knn6.predict(X6_test2) # predicted value of testing set
y6_test_pred = knn6.predict(X6_test) # predicted value of testing set
# Test set2 performance
knn6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
knn6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
knn6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score

# %%
#S6
#logistic regression
from sklearn.linear_model import LogisticRegression
logreg6 = LogisticRegression(solver='newton-cg',max_iter=2500,penalty='none',C=100)
logreg6.fit(X6_train, y6_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y6_test2_pred = logreg6.predict(X6_test2) # predicted value of testing set
y6_test_pred = logreg6.predict(X6_test) # predicted value of testing set
# Test set2 performance
logreg6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
logreg6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
logreg6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(

# %%
#S7
#SVM

from sklearn.svm import SVC

svm_rbf7 = SVC( C = 100, gamma=5, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf7.fit(X7_train, y7_train)
# Make predictions
y7_test2_pred = svm_rbf7.predict(X7_test2)
y7_test_pred = svm_rbf7.predict(X7_test)
# Test set2 performance
svm_rbf7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
svm_rbf7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
svm_rbf7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score

# %%
#S7
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt7 = DecisionTreeClassifier(max_depth=17, criterion = 'entropy', min_samples_leaf= 2) # Define classifier
dt7.fit(X7_train, y7_train) # Train model

# Make predictions
y7_test2_pred = dt7.predict(X7_test2)
y7_test_pred = dt7.predict(X7_test)


# Test set2 performance
dt7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
dt7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score

# Test set performance
dt7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
dt7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score

# %%
#S7
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn7 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 3, weights='distance')# Define classifier taking nearest neighbour of k as 3
knn7.fit(X7_train, y7_train) # Train model, x-> features y->classification or class level

# Make predictions
y7_test2_pred = knn7.predict(X7_test2) # predicted value of testing set
y7_test_pred = knn7.predict(X7_test) # predicted value of testing set



# Test set2 performance
knn7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
knn7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score


# Test set performance
knn7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
knn7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score

# %%
#S7
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg7 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg7.fit(X7_train, y7_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y7_test2_pred = logreg7.predict(X7_test2) # predicted value of testing set
y7_test_pred = logreg7.predict(X7_test) # predicted value of testing set



# Test set2 performance
logreg7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
logreg7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score


# Test set performance
logreg7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
logreg7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S8
#SVM

from sklearn.svm import SVC
svm_rbf8 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf8.fit(X8_train, y8_train)
# Make predictions
y8_test2_pred = svm_rbf8.predict(X8_test2)
y8_test_pred = svm_rbf8.predict(X8_test)


# Test set2 performance
svm_rbf8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
svm_rbf8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
svm_rbf8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score

# %%
#S8
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt8 = DecisionTreeClassifier(max_depth=25, criterion = 'entropy', min_samples_leaf= 3) # Define classifier
dt8.fit(X8_train, y8_train) # Train model

# Make predictions
y8_test2_pred = dt8.predict(X8_test2)
y8_test_pred = dt8.predict(X8_test)
# Test set2 performance
dt8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
dt8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
dt8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score

# %%
#S8
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn8 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 3, weights='distance')# Define classifier taking nearest neighbour of k as 3
knn8.fit(X8_train, y8_train) # Train model, x-> features y->classification or class level
# Make predictions
y8_test2_pred = knn8.predict(X8_test2) # predicted value of testing set
y8_test_pred = knn8.predict(X8_test) # predicted value of testing set
# Test set2 performance
knn8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
knn8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
knn8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score

# %%
#S8
#logistic regression
from sklearn.linear_model import LogisticRegression
logreg8 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg8.fit(X8_train, y8_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y8_test2_pred = logreg8.predict(X8_test2) # predicted value of testing set
y8_test_pred = logreg8.predict(X8_test) # predicted value of testing set
# Test set2 performance
logreg8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
logreg8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score


# Test set performance
logreg8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
logreg8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S9
#SVM

from sklearn.svm import SVC

svm_rbf9 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf9.fit(X9_train, y9_train)
# Make predictions
y9_test2_pred = svm_rbf9.predict(X9_test2)
y9_test_pred = svm_rbf9.predict(X9_test)
# Test set2 performance
svm_rbf9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
svm_rbf9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
svm_rbf9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score

# %%
# S9
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt9 = DecisionTreeClassifier(max_depth=15, criterion = 'entropy', min_samples_leaf= 3) # Define classifier
dt9.fit(X9_train, y9_train) # Train model
# Make predictions
y9_test2_pred = dt9.predict(X9_test2)
y9_test_pred = dt9.predict(X9_test)
# Test set2 performance
dt9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
dt9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
dt9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score

# %%
#S9
#K nearest neighbors

from sklearn.neighbors import KNeighborsClassifier
knn9 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 3, weights='distance')# Define classifier taking nearest neighbour of k as 3
knn9.fit(X9_train, y9_train) # Train model, x-> features y->classification or class level
# Make predictions
y9_test2_pred = knn9.predict(X9_test2) # predicted value of testing set
y9_test_pred = knn9.predict(X9_test) # predicted value of testing set
# Test set2 performance
knn9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
knn9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
knn9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score

# %%
#S9
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg9 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg9.fit(X9_train, y9_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y9_test2_pred = logreg9.predict(X9_test2) # predicted value of testing set
y9_test_pred = logreg9.predict(X9_test) # predicted value of testing set
# Test set2 performance
logreg9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
logreg9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
logreg9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S10
#SVM

from sklearn.svm import SVC

svm_rbf10 = SVC( C = 1000, gamma= 1, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf10.fit(X10_train, y10_train)

# Make predictions
y10_test2_pred = svm_rbf10.predict(X10_test2)
y10_test_pred = svm_rbf10.predict(X10_test)
# Test set2 performance
svm_rbf10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
svm_rbf10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
svm_rbf10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score

# %%
#S10
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt10 = DecisionTreeClassifier(max_depth=15, criterion = 'entropy', min_samples_leaf= 3) # Define classifier
dt10.fit(X10_train, y10_train) # Train model
# Make predictions
y10_test2_pred = dt10.predict(X10_test2)
y10_test_pred = dt10.predict(X10_test)
# Test set2 performance
dt10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
dt10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
dt10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score

# %%
#S10
#K nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
knn10 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn10.fit(X10_train, y10_train) # Train model, x-> features y->classification or class level
# Make predictions
y10_test2_pred = knn10.predict(X10_test2) # predicted value of testing set
y10_test_pred = knn10.predict(X10_test) # predicted value of testing set
# Test set2 performance
knn10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
knn10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
knn10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score

# %%
#s10
#logistic regression
from sklearn.linear_model import LogisticRegression
logreg10 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg10.fit(X10_train, y10_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y10_test2_pred = logreg10.predict(X10_test2) # predicted value of testing set
y10_test_pred = logreg10.predict(X10_test) # predicted value of testing set
# Test set2 performance
logreg10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
logreg10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
logreg10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S11
#SVM

from sklearn.svm import SVC
svm_rbf11 = SVC( C = 1000, gamma=5, class_weight = 'balanced', kernel='rbf',probability=True)
svm_rbf11.fit(X11_train, y11_train)
# Make predictions
y11_test2_pred = svm_rbf11.predict(X11_test2)
y11_test_pred = svm_rbf11.predict(X11_test)
# Test set2 performance
svm_rbf11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
svm_rbf11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set1 performance
svm_rbf11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
svm_rbf11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score

# %%
#S11
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt11 = DecisionTreeClassifier(max_depth=50, criterion = 'entropy', min_samples_leaf= 2) # Define classifier
dt11.fit(X11_train, y11_train) # Train model
# Make predictions
y11_test2_pred = dt11.predict(X11_test2)
y11_test_pred = dt11.predict(X11_test)
# Test set2 performance
dt11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
dt11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
dt11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
dt11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score

# %%
#S11
#K nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
knn11 = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 1, weights='uniform')# Define classifier taking nearest neighbour of k as 3
knn11.fit(X11_train, y11_train) # Train model, x-> features y->classification or class level
# Make predictions
y11_test2_pred = knn11.predict(X11_test2) # predicted value of testing set
y11_test_pred = knn11.predict(X11_test) # predicted value of testing set
# Test set2 performance
knn11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
knn11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
knn11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
knn11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score

# %%
#S11
#logistic regression
from sklearn.linear_model import LogisticRegression

logreg11 = LogisticRegression(solver='lbfgs',max_iter=2500,penalty='none',C=100)
logreg11.fit(X11_train, y11_train) # Train model, x-> features y->classification or class level
?
# Make predictions
y11_test2_pred = logreg11.predict(X11_test2) # predicted value of testing set
y11_test_pred = logreg11.predict(X11_test) # predicted value of testing set
# Test set2 performance
logreg11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
logreg11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set performance
logreg11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
logreg11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#S1
# META RF without fine tune
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

#rf = RandomForestClassifier(max_features= 5, n_estimators=200) # Define classifier without tuned param
#rf.fit(X_train, y_train)

estimator_list1 = [
    ('knn1',knn1),
    ('svm_rbf1',svm_rbf1),
    ('dt1',dt1),
    ('logreg1',logreg1) ]

# Build stack model
stack1_model1 = StackingClassifier(
    estimators=estimator_list1, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model1.fit(X1_train, y1_train)

# Make predictions
y1_test2_pred = stack1_model1.predict(X1_test2)
y1_test_pred = stack1_model1.predict(X1_test)


# Test set2 model performance
stack1_model1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
stack1_model1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score

# Test set model performance
stack1_model1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
stack1_model1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
# Define estimators for stacking model
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier

estimator_list = [
    ('knn1',knn1),
    ('svm_rbf1',svm_rbf1),
    ('dt1',dt1),
    ('logreg1',logreg1) ]

# Build stack model
stack2_model1 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model1.fit(X1_train, y1_train)
# Make predictions
y1_test2_pred = stack2_model1.predict(X1_test2)
y1_test_pred = stack2_model1.predict(X1_test)
# Test set2 model performance
stack2_model1_test2_accuracy = accuracy_score(y1_test2, y1_test2_pred) # Calculate Accuracy
stack2_model1_test2_f1 = f1_score(y1_test2, y1_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model1_test_accuracy = accuracy_score(y1_test, y1_test_pred) # Calculate Accuracy
stack2_model1_test_f1 = f1_score(y1_test, y1_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S2
# META RF without fine tune
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

#rf = RandomForestClassifier(max_features= 5, n_estimators=200) # Define classifier without tuned param
#rf.fit(X_train, y_train)

estimator_list1 = [
    ('knn2',knn2),
    ('svm_rbf2',svm_rbf2),
    ('dt2',dt2),
    ('logreg2',logreg2) ]

# Build stack model
stack1_model2 = StackingClassifier(
    estimators=estimator_list1, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model2.fit(X2_train, y2_train)

# Make predictions
y2_test2_pred = stack1_model2.predict(X2_test2)
y2_test_pred = stack1_model2.predict(X2_test)


# Test set2 model performance
stack1_model2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
stack1_model2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score

# Test set model performance
stack1_model2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
stack1_model2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S2
# META RF without fine tune
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

#rf = RandomForestClassifier(max_features= 5, n_estimators=200) # Define classifier without tuned param
#rf.fit(X_train, y_train)

estimator_list1 = [
    ('knn2',knn2),
    ('svm_rbf2',svm_rbf2),
    ('dt2',dt2),
    ('logreg2',logreg2) ]

# Build stack model
stack2_model2 = StackingClassifier(
    estimators=estimator_list1,  final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model2.fit(X2_train, y2_train)

# Make predictions
y2_test2_pred = stack1_model2.predict(X2_test2)
y2_test_pred = stack1_model2.predict(X2_test)


# Test set2 model performance
stack2_model2_test2_accuracy = accuracy_score(y2_test2, y2_test2_pred) # Calculate Accuracy
stack2_model2_test2_f1 = f1_score(y2_test2, y2_test2_pred, average='weighted') # Calculate F1-score

# Test set model performance
stack2_model2_test_accuracy = accuracy_score(y2_test, y2_test_pred) # Calculate Accuracy
stack2_model2_test_f1 = f1_score(y2_test, y2_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S3
# META RF 
estimator_list1 = [
    ('knn3',knn3),
    ('svm_rbf3',svm_rbf3),
    ('dt3',dt3),
    ('logreg3',logreg3) ]
# Build stack model
stack1_model3 = StackingClassifier(
    estimators=estimator_list1, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model3.fit(X3_train, y3_train)
# Make predictions
y3_test2_pred = stack1_model3.predict(X3_test2)
y3_test_pred = stack1_model3.predict(X3_test)
# Test set2 model performance
stack1_model3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
stack1_model3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
stack1_model3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S3
# META MLP 

estimator_list1 = [
    ('knn3',knn3),
    ('svm_rbf3',svm_rbf3),
    ('dt3',dt3),
    ('logreg3',logreg3) ]
# Build stack model
stack2_model3 = StackingClassifier(
    estimators=estimator_list1, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model3.fit(X3_train, y3_train)
# Make predictions
y3_test2_pred = stack2_model3.predict(X3_test2)
y3_test_pred = stack2_model3.predict(X3_test)
# Test set2 model performance
stack2_model3_test2_accuracy = accuracy_score(y3_test2, y3_test2_pred) # Calculate Accuracy
stack2_model3_test2_f1 = f1_score(y3_test2, y3_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model3_test_accuracy = accuracy_score(y3_test, y3_test_pred) # Calculate Accuracy
stack2_model3_test_f1 = f1_score(y3_test, y3_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S4
# META RF 
estimator_list = [
    ('knn4',knn4),
    ('svm_rbf4',svm_rbf4),
    ('dt4',dt4),
    ('logreg4',logreg4) ]

# Build stack model
stack1_model4 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model4.fit(X4_train, y4_train)
# Make predictions
y4_test2_pred = stack1_model4.predict(X4_test2)
y4_test_pred = stack1_model4.predict(X4_test)
# Test set2 model performance
stack1_model4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
stack1_model4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
stack1_model4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S4
# META RF 
estimator_list = [
    ('knn4',knn4),
    ('svm_rbf4',svm_rbf4),
    ('dt4',dt4),
    ('logreg4',logreg4) ]
# Build stack model
stack2_model4 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model4.fit(X4_train, y4_train)
# Make predictions
y4_test2_pred = stack2_model4.predict(X4_test2)
y4_test_pred = stack2_model4.predict(X4_test)
# Test set2 model performance
stack2_model4_test2_accuracy = accuracy_score(y4_test2, y4_test2_pred) # Calculate Accuracy
stack2_model4_test2_f1 = f1_score(y4_test2, y4_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model4_test_accuracy = accuracy_score(y4_test, y4_test_pred) # Calculate Accuracy
stack2_model4_test_f1 = f1_score(y4_test, y4_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S5
# META RF 
estimator_list = [
    ('knn5',knn5),
    ('svm_rbf5',svm_rbf5),
    ('dt5',dt5),
    ('logreg5',logreg5) ]

# Build stack model
stack1_model5 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model5.fit(X5_train, y5_train)
# Make predictions
y5_test2_pred = stack1_model5.predict(X5_test2)
y5_test_pred = stack1_model5.predict(X5_test)
# Test set2 model performance
stack1_model5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
stack1_model5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
stack1_model5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
# META RF 
estimator_list = [
    ('knn5',knn5),
    ('svm_rbf5',svm_rbf5),
    ('dt5',dt5),
    ('logreg5',logreg5) ]
# Build stack model
stack2_model5 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model5.fit(X5_train, y5_train)
# Make predictions
y5_test2_pred = stack2_model5.predict(X5_test2)
y5_test_pred = stack2_model5.predict(X5_test)
# Test set2 model performance
stack2_model5_test2_accuracy = accuracy_score(y5_test2, y5_test2_pred) # Calculate Accuracy
stack2_model5_test2_f1 = f1_score(y5_test2, y5_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model5_test_accuracy = accuracy_score(y5_test, y5_test_pred) # Calculate Accuracy
stack2_model5_test_f1 = f1_score(y5_test, y5_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S6
# META RF 
estimator_list = [
    ('knn6',knn6),
    ('svm_rbf6',svm_rbf6),
    ('dt6',dt6),
    ('logreg6',logreg6) ]

# Build stack model
stack1_model6 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model6.fit(X6_train, y6_train)
# Make predictions
y6_test2_pred = stack1_model6.predict(X6_test2)
y6_test_pred = stack1_model6.predict(X6_test)
# Test set2 model performance
stack1_model6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
stack1_model6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
stack1_model6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S6
# META MLP 
estimator_list = [
    ('knn6',knn6),
    ('svm_rbf6',svm_rbf6),
    ('dt6',dt6),
    ('logreg6',logreg6) ]

# Build stack model
stack2_model6 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model6.fit(X6_train, y6_train)
# Make predictions
y6_test2_pred = stack2_model6.predict(X6_test2)
y6_test_pred = stack2_model6.predict(X6_test)
# Test set2 model performance
stack2_model6_test2_accuracy = accuracy_score(y6_test2, y6_test2_pred) # Calculate Accuracy
stack2_model6_test2_f1 = f1_score(y6_test2, y6_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model6_test_accuracy = accuracy_score(y6_test, y6_test_pred) # Calculate Accuracy
stack2_model6_test_f1 = f1_score(y6_test, y6_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S7
# META RF 
estimator_list = [
    ('knn7',knn7),
    ('svm_rbf7',svm_rbf7),
    ('dt7',dt7),
    ('logreg7',logreg7)]


# Build stack model
stack1_model7 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model7.fit(X7_train, y7_train)
# Make predictions
y7_test2_pred = stack1_model7.predict(X7_test2)
y7_test_pred = stack1_model7.predict(X7_test)
# Test set2 model performance
stack1_model7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
stack1_model7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
stack1_model7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S7
# META MLP 
estimator_list = [
    ('knn7',knn7),
    ('svm_rbf7',svm_rbf7),
    ('dt7',dt7),
    ('logreg7',logreg7)]

# Build stack model
stack2_model7 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model7.fit(X7_train, y7_train)
# Make predictions
y7_test2_pred = stack2_model7.predict(X7_test2)
y7_test_pred = stack2_model7.predict(X7_test)
# Test set2 model performance
stack2_model7_test2_accuracy = accuracy_score(y7_test2, y7_test2_pred) # Calculate Accuracy
stack2_model7_test2_f1 = f1_score(y7_test2, y7_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model7_test_accuracy = accuracy_score(y7_test, y7_test_pred) # Calculate Accuracy
stack2_model7_test_f1 = f1_score(y7_test, y7_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S8
# META RF 
estimator_list = [
    ('knn8',knn8),
    ('svm_rbf8',svm_rbf8),
    ('dt8',dt8),
    ('logreg8',logreg8)]


# Build stack model
stack1_model8 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model8.fit(X8_train, y8_train)
# Make predictions
y8_test2_pred = stack1_model8.predict(X8_test2)
y8_test_pred = stack1_model8.predict(X8_test)
# Test set2 model performance
stack1_model8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
stack1_model8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
stack1_model8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S8
# META MLP 
estimator_list = [
    ('knn8',knn8),
    ('svm_rbf8',svm_rbf8),
    ('dt8',dt8),
    ('logreg8',logreg8)]

# Build stack model
stack2_model8 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model8.fit(X8_train, y8_train)
# Make predictions
y8_test2_pred = stack2_model8.predict(X8_test2)
y8_test_pred = stack2_model8.predict(X8_test)
# Test set2 model performance
stack2_model8_test2_accuracy = accuracy_score(y8_test2, y8_test2_pred) # Calculate Accuracy
stack2_model8_test2_f1 = f1_score(y8_test2, y8_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model8_test_accuracy = accuracy_score(y8_test, y8_test_pred) # Calculate Accuracy
stack2_model8_test_f1 = f1_score(y8_test, y8_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S9
# META RF 
estimator_list = [
    ('knn9',knn9),
    ('svm_rbf9',svm_rbf9),
    ('dt9',dt9),
    ('logreg9',logreg9)]


# Build stack model
stack1_model9 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model9.fit(X9_train, y9_train)
# Make predictions
y9_test2_pred = stack1_model9.predict(X9_test2)
y9_test_pred = stack1_model9.predict(X9_test)
# Test set2 model performance
stack1_model9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
stack1_model9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
stack1_model9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S9
# META MLP 
estimator_list = [
    ('knn9',knn9),
    ('svm_rbf9',svm_rbf9),
    ('dt9',dt9),
    ('logreg9',logreg9)]

# Build stack model
stack2_model9 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model9.fit(X9_train, y9_train)
# Make predictions
y9_test2_pred = stack2_model9.predict(X9_test2)
y9_test_pred = stack2_model9.predict(X9_test)
# Test set2 model performance
stack2_model9_test2_accuracy = accuracy_score(y9_test2, y9_test2_pred) # Calculate Accuracy
stack2_model9_test2_f1 = f1_score(y9_test2, y9_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model9_test_accuracy = accuracy_score(y9_test, y9_test_pred) # Calculate Accuracy
stack2_model9_test_f1 = f1_score(y9_test, y9_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S10
# META RF 
estimator_list = [
    ('knn10',knn10),
    ('svm_rbf10',svm_rbf10),
    ('dt10',dt10),
    ('logreg10',logreg10)]


# Build stack model
stack1_model10 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model10.fit(X10_train, y10_train)
# Make predictions
y10_test2_pred = stack1_model10.predict(X10_test2)
y10_test_pred = stack1_model10.predict(X10_test)
# Test set2 model performance
stack1_model10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
stack1_model10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
stack1_model10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S10
# META MLP 
estimator_list = [
    ('knn10',knn10),
    ('svm_rbf10',svm_rbf10),
    ('dt10',dt10),
    ('logreg10',logreg10)]

# Build stack model
stack2_model10 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model10.fit(X10_train, y10_train)
# Make predictions
y10_test2_pred = stack2_model10.predict(X10_test2)
y10_test_pred = stack2_model10.predict(X10_test)
# Test set2 model performance
stack2_model10_test2_accuracy = accuracy_score(y10_test2, y10_test2_pred) # Calculate Accuracy
stack2_model10_test2_f1 = f1_score(y10_test2, y10_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model10_test_accuracy = accuracy_score(y10_test, y10_test_pred) # Calculate Accuracy
stack2_model10_test_f1 = f1_score(y10_test, y10_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S11
# META RF 
estimator_list = [
    ('knn11',knn11),
    ('svm_rbf11',svm_rbf11),
    ('dt11',dt11),
    ('logreg11',logreg11)]


# Build stack model
stack1_model11 = StackingClassifier(
    estimators=estimator_list, final_estimator=RandomForestClassifier()
)
# Train stacked model
stack1_model11.fit(X11_train, y11_train)
# Make predictions
y11_test2_pred = stack1_model11.predict(X11_test2)
y11_test_pred = stack1_model11.predict(X11_test)
# Test set2 model performance
stack1_model11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
stack1_model11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack1_model11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
stack1_model11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
#S11
# META MLP 
estimator_list = [
    ('knn11',knn11),
    ('svm_rbf11',svm_rbf11),
    ('dt11',dt11),
    ('logreg11',logreg11)]

# Build stack model
stack2_model11 = StackingClassifier(
    estimators=estimator_list, final_estimator=MLPClassifier()
)
# Train stacked model
stack2_model11.fit(X11_train, y11_train)
# Make predictions
y11_test2_pred = stack2_model11.predict(X11_test2)
y11_test_pred = stack2_model11.predict(X11_test)
# Test set2 model performance
stack2_model11_test2_accuracy = accuracy_score(y11_test2, y11_test2_pred) # Calculate Accuracy
stack2_model11_test2_f1 = f1_score(y11_test2, y11_test2_pred, average='weighted') # Calculate F1-score
# Test set model performance
stack2_model11_test_accuracy = accuracy_score(y11_test, y11_test_pred) # Calculate Accuracy
stack2_model11_test_f1 = f1_score(y11_test, y11_test_pred, average='weighted') # Calculate F1-score
# Out:
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\anind\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\_logistic.py:1483: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# ...

# %%
# for RF test set1
acc_test_list = {'stack1_model1':stack1_model1_test_accuracy,
                 'stack1_model2':stack1_model2_test_accuracy,
                 'stack1_model3':stack1_model3_test_accuracy,
                 'stack1_model4':stack1_model4_test_accuracy,
                 'stack1_model5':stack1_model5_test_accuracy,
                 'stack1_model6':stack1_model6_test_accuracy,
                 'stack1_model7':stack1_model7_test_accuracy,
                 'stack1_model8':stack1_model8_test_accuracy,
                 'stack1_model9':stack1_model9_test_accuracy,
                 'stack1_model10':stack1_model10_test_accuracy,
                 'stack1_model11':stack1_model11_test_accuracy,
}

f1_test_list = {'stack1_model1':stack1_model1_test_f1,
                'stack1_model2':stack1_model2_test_f1,
                'stack1_model3':stack1_model3_test_f1,
                'stack1_model4':stack1_model4_test_f1,
                'stack1_model5':stack1_model5_test_f1,
                'stack1_model6':stack1_model6_test_f1,
                'stack1_model7':stack1_model7_test_f1,
                'stack1_model8':stack1_model8_test_f1,
                'stack1_model9':stack1_model9_test_f1,
                'stack1_model10':stack1_model10_test_f1,
                'stack1_model11':stack1_model11_test_f1,
}

# %%
# for RF test set2
acc_test2_list = {'stack1_model1':stack1_model1_test2_accuracy,
                 'stack1_model2':stack1_model2_test2_accuracy,
                 'stack1_model3':stack1_model3_test2_accuracy,
                 'stack1_model4':stack1_model4_test2_accuracy,
                 'stack1_model5':stack1_model5_test2_accuracy,
                 'stack1_model6':stack1_model6_test2_accuracy,
                 'stack1_model7':stack1_model7_test2_accuracy,
                 'stack1_model8':stack1_model8_test2_accuracy,
                 'stack1_model9':stack1_model9_test2_accuracy,
                 'stack1_model10':stack1_model10_test2_accuracy,
                 'stack1_model11':stack1_model11_test2_accuracy,
}

f1_test2_list = {'stack1_model1':stack1_model1_test2_f1,
                'stack1_model2':stack1_model2_test2_f1,
                'stack1_model3':stack1_model3_test2_f1,
                'stack1_model4':stack1_model4_test2_f1,
                'stack1_model5':stack1_model5_test2_f1,
                'stack1_model6':stack1_model6_test2_f1,
                'stack1_model7':stack1_model7_test2_f1,
                'stack1_model8':stack1_model8_test2_f1,
                'stack1_model9':stack1_model9_test2_f1,
                'stack1_model10':stack1_model10_test2_f1,
                'stack1_model11':stack1_model11_test2_f1,
}

# %%
# for MLP test set1
acc_test3_list = {'stack2_model1':stack2_model1_test_accuracy,
                 'stack2_model2':stack2_model2_test_accuracy,
                 'stack2_model3':stack2_model3_test_accuracy,
                 'stack2_model4':stack2_model4_test_accuracy,
                 'stack2_model5':stack2_model5_test_accuracy,
                 'stack2_model6':stack2_model6_test_accuracy,
                 'stack2_model7':stack2_model7_test_accuracy,
                 'stack2_model8':stack2_model8_test_accuracy,
                 'stack2_model9':stack2_model9_test_accuracy,
                 'stack2_model10':stack2_model10_test_accuracy,
                 'stack2_model11':stack2_model11_test_accuracy,
}

f1_test3_list = {'stack2_model1':stack2_model1_test_f1,
                'stack2_model2':stack2_model2_test_f1,
                'stack2_model3':stack2_model3_test_f1,
                'stack2_model4':stack2_model4_test_f1,
                'stack2_model5':stack2_model5_test_f1,
                'stack2_model6':stack2_model6_test_f1,
                'stack2_model7':stack2_model7_test_f1,
                'stack2_model8':stack2_model8_test_f1,
                'stack2_model9':stack2_model9_test_f1,
                'stack2_model10':stack2_model10_test_f1,
                'stack2_model11':stack2_model11_test_f1,
}

# %%
# for MLP test set2
acc_test4_list = {'stack2_model1':stack2_model1_test2_accuracy,
                 'stack2_model2':stack2_model2_test2_accuracy,
                 'stack2_model3':stack2_model3_test2_accuracy,
                 'stack2_model4':stack2_model4_test2_accuracy,
                 'stack2_model5':stack2_model5_test2_accuracy,
                 'stack2_model6':stack2_model6_test2_accuracy,
                 'stack2_model7':stack2_model7_test2_accuracy,
                 'stack2_model8':stack2_model8_test2_accuracy,
                 'stack2_model9':stack2_model9_test2_accuracy,
                 'stack2_model10':stack2_model10_test2_accuracy,
                 'stack2_model11':stack2_model11_test2_accuracy,
}

f1_test4_list = {'stack2_model1':stack2_model1_test2_f1,
                'stack2_model2':stack2_model2_test2_f1,
                'stack2_model3':stack2_model3_test2_f1,
                'stack2_model4':stack2_model4_test2_f1,
                'stack2_model5':stack2_model5_test2_f1,
                'stack2_model6':stack2_model6_test2_f1,
                'stack2_model7':stack2_model7_test2_f1,
                'stack2_model8':stack2_model8_test2_f1,
                'stack2_model9':stack2_model9_test2_f1,
                'stack2_model10':stack2_model10_test2_f1,
                'stack2_model11':stack2_model11_test2_f1,
}

# %%
# All KNN for test set 1
acc_test5_list = {'knn1':knn1_test_accuracy,
                  'knn2':knn2_test_accuracy,
                  'knn3':knn3_test_accuracy,
                  'knn4':knn4_test_accuracy,
                  'knn5':knn5_test_accuracy,
                  'knn6':knn6_test_accuracy,
                  'knn7':knn7_test_accuracy,
                  'knn8':knn8_test_accuracy,
                  'knn9':knn9_test_accuracy,
                  'knn10':knn10_test_accuracy,
                  'knn11':knn11_test_accuracy,
}

f1_test5_list = {'knn1':knn1_test_f1,
                'knn2':knn2_test_f1,
                'knn3':knn3_test_f1,
                'knn4':knn4_test_f1,
                'knn5':knn5_test_f1,
                'knn6':knn6_test_f1,
                'knn7':knn7_test_f1,
                'knn8':knn8_test_f1,
                'knn9':knn9_test_f1,
                'knn10':knn10_test_f1,
                'knn11':knn11_test_f1,
}
# All KNN for test set 2
acc_test6_list = {'knn1':knn1_test2_accuracy,
                  'knn2':knn2_test2_accuracy,
                  'knn3':knn3_test2_accuracy,
                  'knn4':knn4_test2_accuracy,
                  'knn5':knn5_test2_accuracy,
                  'knn6':knn6_test2_accuracy,
                  'knn7':knn7_test2_accuracy,
                  'knn8':knn8_test2_accuracy,
                  'knn9':knn9_test2_accuracy,
                  'knn10':knn10_test2_accuracy,
                  'knn11':knn11_test2_accuracy,
}

f1_test6_list = {'knn1':knn1_test2_f1,
                'knn2':knn2_test2_f1,
                'knn3':knn3_test2_f1,
                'knn4':knn4_test2_f1,
                'knn5':knn5_test2_f1,
                'knn6':knn6_test2_f1,
                'knn7':knn7_test2_f1,
                'knn8':knn8_test2_f1,
                'knn9':knn9_test2_f1,
                'knn10':knn10_test2_f1,
                'knn11':knn11_test2_f1,
}

# %%
# For all SVM For test set 1
acc_test7_list = {
    'svm_rbf1': svm_rbf1_test_accuracy,
    'svm_rbf2': svm_rbf2_test_accuracy,
    'svm_rbf3': svm_rbf3_test_accuracy,
    'svm_rbf4': svm_rbf4_test_accuracy,
    'svm_rbf5': svm_rbf5_test_accuracy,
    'svm_rbf6': svm_rbf6_test_accuracy,
    'svm_rbf7': svm_rbf7_test_accuracy,
    'svm_rbf8': svm_rbf8_test_accuracy,
    'svm_rbf9': svm_rbf9_test_accuracy,
    'svm_rbf10': svm_rbf10_test_accuracy,
    'svm_rbf11': svm_rbf11_test_accuracy,
}

f1_test7_list = {
                'svm_rbf1': svm_rbf1_test_f1,
                'svm_rbf2': svm_rbf2_test_f1,
                'svm_rbf3': svm_rbf3_test_f1,
                'svm_rbf4': svm_rbf4_test_f1,
                'svm_rbf5': svm_rbf5_test_f1,
                'svm_rbf6': svm_rbf6_test_f1,
                'svm_rbf7': svm_rbf7_test_f1,
                'svm_rbf8': svm_rbf8_test_f1,
                'svm_rbf9': svm_rbf9_test_f1,
                'svm_rbf10': svm_rbf10_test_f1,
                'svm_rbf11': svm_rbf11_test_f1,
                }
acc_test8_list = {
    'svm_rbf1': svm_rbf1_test2_accuracy,
    'svm_rbf2': svm_rbf2_test2_accuracy,
    'svm_rbf3': svm_rbf3_test2_accuracy,
    'svm_rbf4': svm_rbf4_test2_accuracy,
    'svm_rbf5': svm_rbf5_test2_accuracy,
    'svm_rbf6': svm_rbf6_test2_accuracy,
    'svm_rbf7': svm_rbf7_test2_accuracy,
    'svm_rbf8': svm_rbf8_test2_accuracy,
    'svm_rbf9': svm_rbf9_test2_accuracy,
    'svm_rbf10': svm_rbf10_test2_accuracy,
    'svm_rbf11': svm_rbf11_test2_accuracy,
}

f1_test8_list = {
                'svm_rbf1': svm_rbf1_test2_f1,
                'svm_rbf2': svm_rbf2_test2_f1,
                'svm_rbf3': svm_rbf3_test2_f1,
                'svm_rbf4': svm_rbf4_test2_f1,
                'svm_rbf5': svm_rbf5_test2_f1,
                'svm_rbf6': svm_rbf6_test2_f1,
                'svm_rbf7': svm_rbf7_test2_f1,
                'svm_rbf8': svm_rbf8_test2_f1,
                'svm_rbf9': svm_rbf9_test2_f1,
                'svm_rbf10': svm_rbf10_test2_f1,
                'svm_rbf11': svm_rbf11_test2_f1,
                }

# %%
# for result
acc_test9_list = {
                 'dt1': dt1_test_accuracy,
                 'dt2': dt2_test_accuracy,
                 'dt3': dt3_test_accuracy,
                 'dt4': dt4_test_accuracy,
                 'dt5': dt5_test_accuracy,
                 'dt6': dt6_test_accuracy,
                 'dt7': dt7_test_accuracy,
                 'dt8': dt8_test_accuracy,
                 'dt9': dt9_test_accuracy,
                 'dt10':dt10_test_accuracy,
                 'dt11':dt11_test_accuracy,
}

f1_test9_list = {
                 'dt1': dt1_test_f1,
                 'dt2': dt2_test_f1,
                 'dt3': dt3_test_f1,
                 'dt4': dt4_test_f1,
                 'dt5': dt5_test_f1,
                 'dt6': dt6_test_f1,
                 'dt7': dt7_test_f1,
                 'dt8': dt8_test_f1,
                 'dt9': dt9_test_f1,
                 'dt10': dt10_test_f1,
                 'dt11': dt11_test_f1,
}
# for test set 2
acc_test10_list = {
                 'dt1': dt1_test2_accuracy,
                 'dt2': dt2_test2_accuracy,
                 'dt3': dt3_test2_accuracy,
                 'dt4': dt4_test2_accuracy,
                 'dt5': dt5_test2_accuracy,
                 'dt6': dt6_test2_accuracy,
                 'dt7': dt7_test2_accuracy,
                 'dt8': dt8_test2_accuracy,
                 'dt9': dt9_test2_accuracy,
                 'dt10':dt10_test2_accuracy,
                 'dt11':dt11_test2_accuracy,
}

f1_test10_list = {
                 'dt1': dt1_test2_f1,
                 'dt2': dt2_test2_f1,
                 'dt3': dt3_test2_f1,
                 'dt4': dt4_test2_f1,
                 'dt5': dt5_test2_f1,
                 'dt6': dt6_test2_f1,
                 'dt7': dt7_test2_f1,
                 'dt8': dt8_test2_f1,
                 'dt9': dt9_test2_f1,
                 'dt10': dt10_test2_f1,
                 'dt11': dt11_test2_f1,
}

# %%
# for Test set 1
acc_test11_list = {
                'logreg1':logreg1_test_accuracy,
                'logreg2':logreg2_test_accuracy,
                'logreg3':logreg3_test_accuracy,
                'logreg4':logreg4_test_accuracy,
                'logreg5':logreg5_test_accuracy,
                'logreg6':logreg6_test_accuracy,
                'logreg7':logreg7_test_accuracy,
                'logreg8':logreg8_test_accuracy,
                'logreg9':logreg9_test_accuracy,
                'logreg10':logreg10_test_accuracy,
                'logreg11':logreg11_test_accuracy
                }

f1_test11_list = {
               
    'logreg1':logreg1_test_f1,
    'logreg2':logreg2_test_f1,
    'logreg3':logreg3_test_f1,
    'logreg4':logreg4_test_f1,
    'logreg5':logreg5_test_f1,
    'logreg6':logreg6_test_f1,
    'logreg7':logreg7_test_f1,
    'logreg8':logreg8_test_f1,
    'logreg9':logreg9_test_f1,
    'logreg10':logreg10_test_f1,
    'logreg11':logreg11_test_f1
               }
# for Test set 2
acc_test12_list = {
                'logreg1':logreg1_test2_accuracy,
                'logreg2':logreg2_test2_accuracy,
                'logreg3':logreg3_test2_accuracy,
                'logreg4':logreg4_test2_accuracy,
                'logreg5':logreg5_test2_accuracy,
                'logreg6':logreg6_test2_accuracy,
                'logreg7':logreg7_test2_accuracy,
                'logreg8':logreg8_test2_accuracy,
                'logreg9':logreg9_test2_accuracy,
                'logreg10':logreg10_test2_accuracy,
                'logreg11':logreg11_test2_accuracy
                }

f1_test12_list = {
               
    'logreg1':logreg1_test2_f1,
    'logreg2':logreg2_test2_f1,
    'logreg3':logreg3_test2_f1,
    'logreg4':logreg4_test2_f1,
    'logreg5':logreg5_test2_f1,
    'logreg6':logreg6_test2_f1,
    'logreg7':logreg7_test2_f1,
    'logreg8':logreg8_test2_f1,
    'logreg9':logreg9_test2_f1,
    'logreg10':logreg10_test2_f1,
    'logreg11':logreg11_test2_f1
               }

# %%
acc_test4_list
# Out:
# {'stack2_model1': 0.9095170454545455,
#  'stack2_model2': 0.9740056818181818,
#  'stack2_model3': 0.9143465909090909,
#  'stack2_model4': 0.9144886363636363,
#  'stack2_model5': 0.8964488636363637,
#  'stack2_model6': 0.9556818181818182,
#  'stack2_model7': 0.8872159090909091,
#  'stack2_model8': 0.9275568181818182,
#  'stack2_model9': 0.9474431818181818,
#  'stack2_model10': 0.9326704545454545,
#  'stack2_model11': 0.9563920454545455}

# %%
#for RF
import pandas as pd

acc1_df = pd.DataFrame.from_dict(acc_test_list, orient='index', columns=['Accuracy test set 1'])
acc2_df = pd.DataFrame.from_dict(acc_test2_list, orient='index', columns=['Accuracy test set 2'])
f11_df = pd.DataFrame.from_dict(f1_test_list, orient='index', columns=['F1 score for test set 1 '])
f12_df = pd.DataFrame.from_dict(f1_test2_list, orient='index', columns=['F1 score for test set 2 '])
df1 = pd.concat([acc1_df, acc2_df, f11_df, f12_df], axis=1)
df1
# Out:
#                 Accuracy test set 1  Accuracy test set 2  \
# stack1_model1              0.799392             0.911648
# stack1_model2              0.937130             0.974006
# stack1_model3              0.764464             0.915341
# stack1_model4              0.765122             0.917756
# stack1_model5              0.754027             0.898864
# stack1_model6              0.903189             0.955540
# stack1_model7              0.729043             0.889205
# stack1_model8              0.842784             0.930824
# stack1_model9              0.844757             0.945739
# stack1_model10             0.821170             0.935653
# stack1_model11             0.876479             0.957386
#
#                 F1 score for test set 1   F1 score for test set 2
# stack1_model1                   0.791604                  0.911031
# stack1_model2                   0.937852                  0.974203
# stack1_model3                   0.757055                  0.914988
# ...

# %%
df1.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.821596
# Accuracy test set 2         0.930178
# F1 score for test set 1     0.814467
# F1 score for test set 2     0.929968
# dtype: float64

# %%
#FOR MLP


import pandas as pd

acc3_df = pd.DataFrame.from_dict(acc_test3_list, orient='index', columns=['Accuracy test set 1'])
acc4_df = pd.DataFrame.from_dict(acc_test4_list, orient='index', columns=['Accuracy test set 2'])
f13_df = pd.DataFrame.from_dict(f1_test3_list, orient='index', columns=['F1 score for test set 1 '])
f14_df = pd.DataFrame.from_dict(f1_test4_list, orient='index', columns=['F1 score for test set 2 '])
df3 = pd.concat([acc3_df, acc4_df, f13_df, f14_df], axis=1)
df3
# Out:
#                 Accuracy test set 1  Accuracy test set 2  \
# stack2_model1              0.794954             0.909517
# stack2_model2              0.937130             0.974006
# stack2_model3              0.763396             0.914347
# stack2_model4              0.760848             0.914489
# stack2_model5              0.745891             0.896449
# stack2_model6              0.901216             0.955682
# stack2_model7              0.726660             0.887216
# stack2_model8              0.830046             0.927557
# stack2_model9              0.846154             0.947443
# stack2_model10             0.807117             0.932670
# stack2_model11             0.874096             0.956392
#
#                 F1 score for test set 1   F1 score for test set 2
# stack2_model1                   0.786149                  0.908848
# stack2_model2                   0.937852                  0.974203
# stack2_model3                   0.755161                  0.913983
# ...

# %%
df3.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.817046
# Accuracy test set 2         0.928706
# F1 score for test set 1     0.810643
# F1 score for test set 2     0.928637
# dtype: float64

# %%
#FOR KNN


import pandas as pd

acc5_df = pd.DataFrame.from_dict(acc_test5_list, orient='index', columns=['Accuracy test set 1'])
acc6_df = pd.DataFrame.from_dict(acc_test6_list, orient='index', columns=['Accuracy test set 2'])
f15_df = pd.DataFrame.from_dict(f1_test5_list, orient='index', columns=['F1 score for test set 1 '])
f16_df = pd.DataFrame.from_dict(f1_test6_list, orient='index', columns=['F1 score for test set 2 '])
df5 = pd.concat([acc5_df, acc6_df, f15_df, f16_df], axis=1)
df5
# Out:
#        Accuracy test set 1  Accuracy test set 2  F1 score for test set 1   \
# knn1              0.733563             0.871449                  0.727533
# knn2              0.902778             0.959801                  0.903300
# knn3              0.730605             0.896449                  0.726470
# knn4              0.739974             0.906960                  0.736456
# knn5              0.711785             0.888210                  0.697523
# knn6              0.839661             0.931250                  0.836372
# knn7              0.686144             0.875000                  0.664449
# knn8              0.788133             0.911790                  0.767686
# knn9              0.780654             0.925000                  0.782679
# knn10             0.750164             0.907528                  0.762010
# knn11             0.886506             0.956108                  0.885216
#
#        F1 score for test set 2
# knn1                   0.870972
# ...

# %%
df5.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.777270
# Accuracy test set 2         0.911777
# F1 score for test set 1     0.771791
# F1 score for test set 2     0.911722
# dtype: float64

# %%
#FOR SVM


import pandas as pd

acc7_df = pd.DataFrame.from_dict(acc_test7_list, orient='index', columns=['Accuracy test set 1'])
acc8_df = pd.DataFrame.from_dict(acc_test8_list, orient='index', columns=['Accuracy test set 2'])
f17_df = pd.DataFrame.from_dict(f1_test7_list, orient='index', columns=['F1 score for test set 1 '])
f18_df = pd.DataFrame.from_dict(f1_test8_list, orient='index', columns=['F1 score for test set 2 '])
df7 = pd.concat([acc7_df, acc8_df, f17_df, f18_df], axis=1)
df7
# Out:
#            Accuracy test set 1  Accuracy test set 2  F1 score for test set 1   \
# svm_rbf1              0.791913             0.904830                  0.783790
# svm_rbf2              0.915845             0.965767                  0.915333
# svm_rbf3              0.733317             0.904830                  0.723713
# svm_rbf4              0.760684             0.912784                  0.753968
# svm_rbf5              0.753945             0.895170                  0.746552
# svm_rbf6              0.896121             0.952557                  0.894233
# svm_rbf7              0.710224             0.883097                  0.671322
# svm_rbf8              0.837607             0.927699                  0.821971
# svm_rbf9              0.838840             0.941903                  0.838524
# svm_rbf10             0.796926             0.924006                  0.801468
# svm_rbf11             0.878698             0.957670                  0.876020
#
# ...

# %%
df7.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.810374
# Accuracy test set 2         0.924574
# F1 score for test set 1     0.802445
# F1 score for test set 2     0.924345
# dtype: float64

# %%
#FOR DT1


import pandas as pd

acc9_df = pd.DataFrame.from_dict(acc_test9_list, orient='index', columns=['Accuracy test set 1'])
acc10_df = pd.DataFrame.from_dict(acc_test10_list, orient='index', columns=['Accuracy test set 2'])
f19_df = pd.DataFrame.from_dict(f1_test9_list, orient='index', columns=['F1 score for test set 1 '])
f110_df = pd.DataFrame.from_dict(f1_test10_list, orient='index', columns=['F1 score for test set 2 '])
df9 = pd.concat([acc9_df, acc10_df, f19_df, f110_df], axis=1)
df9
# Out:
#       Accuracy test set 1  Accuracy test set 2  F1 score for test set 1   \
# dt1              0.733563             0.887074                  0.727533
# dt2              0.898997             0.951420                  0.898776
# dt3              0.734057             0.885085                  0.732672
# dt4              0.657791             0.872017                  0.649076
# dt5              0.656476             0.866193                  0.634193
# dt6              0.836703             0.932670                  0.836011
# dt7              0.635848             0.846165                  0.618887
# dt8              0.758218             0.899432                  0.746821
# dt9              0.703074             0.904403                  0.705096
# dt10             0.820348             0.934375                  0.826645
# dt11             0.822978             0.937500                  0.818865
#
#       F1 score for test set 2
# dt1                   0.886089
# ...

# %%
df9.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.750732
# Accuracy test set 2         0.901485
# F1 score for test set 1     0.744961
# F1 score for test set 2     0.901358
# dtype: float64

# %%
#FOR LR


import pandas as pd

acc11_df = pd.DataFrame.from_dict(acc_test11_list, orient='index', columns=['Accuracy test set 1'])
acc12_df = pd.DataFrame.from_dict(acc_test12_list, orient='index', columns=['Accuracy test set 2'])
f111_df = pd.DataFrame.from_dict(f1_test11_list, orient='index', columns=['F1 score for test set 1 '])
f112_df = pd.DataFrame.from_dict(f1_test12_list, orient='index', columns=['F1 score for test set 2 '])
df11 = pd.concat([acc11_df, acc12_df, f111_df, f112_df], axis=1)
df11
# Out:
#           Accuracy test set 1  Accuracy test set 2  F1 score for test set 1   \
# logreg1              0.843853             0.919318                  0.839622
# logreg2              0.955950             0.971307                  0.955989
# logreg3              0.800542             0.892898                  0.793793
# logreg4              0.775970             0.900994                  0.762390
# logreg5              0.773669             0.893324                  0.761625
# logreg6              0.895546             0.952273                  0.891531
# logreg7              0.761423             0.895597                  0.740094
# logreg8              0.865056             0.918182                  0.868330
# logreg9              0.880999             0.947301                  0.879062
# logreg10             0.872863             0.942614                  0.876388
# logreg11             0.862344             0.949716                  0.850736
#
#           F1 score for test set 2
# ...

# %%
df11.head()
# Out:
#          Accuracy test set 1  Accuracy test set 2  F1 score for test set 1   \
# logreg1             0.843853             0.919318                  0.839622
# logreg2             0.955950             0.971307                  0.955989
# logreg3             0.800542             0.892898                  0.793793
# logreg4             0.775970             0.900994                  0.762390
# logreg5             0.773669             0.893324                  0.761625
#
#          F1 score for test set 2
# logreg1                  0.919306
# logreg2                  0.971401
# logreg3                  0.892198
# logreg4                  0.900566
# logreg5                  0.893667

# %%
df11.iloc[:,0:4].apply(np.mean)
# Out:
# Accuracy test set 1         0.844383
# Accuracy test set 2         0.925775
# F1 score for test set 1     0.838142
# F1 score for test set 2     0.925700
# dtype: float64

# %%
#Base finally contained

#LR
LA1= 0.844383
LA2= 0.925775
LF1=0.838142
LF2=0.925700

#SVM
SA1=0.810374
SA2=0.924574
SF1=0.802445
SF2=0.924345

#DT
DA1=0.750732
DA2=0.901485
DF1=0.744961
DF2=0.901358

#KNN
KA1=0.777270
KA2=0.911777
KF1=0.771791
KF2= 0.911722


#Stack1 RF
S1A1=0.821596
S1A2=0.930178
S1F1=0.814467
S1F2=0.929968


#Stack2 MLP
S2A1=0.817046
S2A2=0.928706
S2F1=0.810643
S2F2=0.928637

# %%
# for result
acc_tests111_list = {'Logistic_regression':LA1,
                     'KNN':KA1,
                     'SVM':SA1,
                     'Desition_Tree':DA1,
                     'stack_model_RF':S1A1,
                 'stack_model_MLP':S2A1
                }
f1_tests111_list = {'Logistic_regression':LF1,
                     'KNN':KF1,
                     'SVM':SF1,
                     'Desition_Tree':DF1,
                    'stack_model_RF':S1F1,
                'stack_model_MLP':S2F1
               }
acc_tests222_list = {'Logistic_regression':LA2,
                     'KNN':KA2,
                     'SVM':SA2,
                     'Desition_Tree':DA2,
                     'stack_model_RF':S1A2,
                 'stack_model_MLP':S2A2
                }
f1_tests222_list = {'Logistic_regression':LF2,
                     'KNN':KF2,
                     'SVM':SF2,
                     'Desition_Tree':DF2,
                    'stack_model_RF':S1F2,
                'stack_model_MLP':S2F2
               }

# %%
#Final Table taking average
import pandas as pd

acc111_df = pd.DataFrame.from_dict(acc_tests111_list, orient='index', columns=['Accuracy test set 1'])
acc222_df = pd.DataFrame.from_dict(acc_tests222_list, orient='index', columns=['Accuracy test set 2'])
f1111_df = pd.DataFrame.from_dict(f1_tests111_list, orient='index', columns=['F1 score for test set 1 '])
f1222_df = pd.DataFrame.from_dict(f1_tests222_list, orient='index', columns=['F1 score for test set 2 '])
df111 = pd.concat([acc111_df, acc222_df, f1111_df, f1222_df], axis=1)
df111
# Out:
#                      Accuracy test set 1  Accuracy test set 2  \
# Logistic_regression             0.844383             0.925775
# KNN                             0.777270             0.911777
# SVM                             0.810374             0.924574
# Desition_Tree                   0.750732             0.901485
# stack_model_RF                  0.821596             0.930178
# stack_model_MLP                 0.817046             0.928706
#
#                      F1 score for test set 1   F1 score for test set 2
# Logistic_regression                  0.838142                  0.925700
# KNN                                  0.771791                  0.911722
# SVM                                  0.802445                  0.924345
# Desition_Tree                        0.744961                  0.901358
# stack_model_RF                       0.814467                  0.929968
# stack_model_MLP                      0.810643                  0.928637

# %%
df111.apply(np.max)
# Out:
# Accuracy test set 1         0.844383
# Accuracy test set 2         0.930178
# F1 score for test set 1     0.838142
# F1 score for test set 2     0.929968
# dtype: float64
